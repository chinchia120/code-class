# %% [markdown]
# # **Assignment 5. Residual Network**
#
# * 看懂Residual Network樣板程式，解析其網路結構。
# * 基於樣板設計一個Residual Network, 與作業四VGG模型進行分析與比較(那個模型較好，為什麼?)。
# * (Optional)比較多個不同深度Residual Networks (以Residual Block為單位)，檢視”Deeper is Better”是否成立。

# %%
# Import
import os, torch
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from google.colab import drive
from keras.datasets import cifar10
from tensorflow.keras import regularizers, initializers, optimizers, metrics, utils
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, Input, Add, AveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Set Direction
drive.mount('/content/gdrive')
#os.chdir('/content/gdrive/My Drive/data/tmp/Introduction-to-Machine-Learning/homework/HW5')
os.chdir('/content/gdrive/My Drive/data/HW5')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Loading the CIFAR-10 Dataset
(x_train_image, y_train_label), (x_test_image, y_test_label) = cifar10.load_data()

# Declare Variables
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

def plot_multiimages(images, labels, prediction, idx, num=32):
    fig, ax = plt.subplots(4, 8, figsize=(12, 6))
    if num > 32: num = 32
    for i in range(0, num):
        ax = plt.subplot(4,8, 1+i)
        ax.imshow(images[idx])
        title = "l = " + class_names[int(labels[idx])]
        if len(prediction) > 0:
            title = "l = {}, p = {}".format(class_names[int(labels[idx])], class_names[prediction[idx]])
        else:
            title = "l = {}".format(class_names[int(labels[idx])])
        ax.set_title(title, fontsize=8)
        ax.set_xticks([]); ax.set_yticks([])
        idx+=1
    plt.tight_layout()
    plt.show()

plot_multiimages(x_test_image, y_test_label, [], 500, 32)

# Convert and Pre-Processing
x_train = x_train_image.reshape(len(x_train_image), 32, 32, 3).astype('float32')
x_test = x_test_image.reshape(len(x_test_image), 32, 32, 3).astype('float32')
x_train_norm = x_train / 255
x_test_norm = x_test / 255
y_TrainOneHot = utils.to_categorical(y_train_label)
y_TestOneHot = utils.to_categorical(y_test_label)

# %%
# Build a ResNet
def identity_block(X, filters):
    # Retrieve Filters
    F1, F2, F3 = filters
    # Save the Input Value
    X_shortcut = X

    # First Component of Main Path
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Second Component of Main Path
    X = Conv2D(filters=F2, kernel_size=(3, 3), strides=(1, 1), padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Third Component of Main Path
    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='same')(X)
    X = BatchNormalization()(X)

    # Final Step: Add Shortcut Value to Main Path, and Pass It Through a RELU Activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

def convolutional_block(X, filters):
    # Retrieve Filters
    F1, F2, F3 = filters
    # Save the Input Value
    X_shortcut = X

    ##### MAIN PATH #####
    # First Component of Main Path
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(2, 2), padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Second Component of Main Path
    X = Conv2D(filters=F2, kernel_size=(3, 3), strides=(1, 1), padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Third Component of Main Path
    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='same')(X)
    X = BatchNormalization()(X)

    ##### SHORTCUT PATH ####
    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(2, 2), padding='same')(X_shortcut)
    X_shortcut = BatchNormalization()(X_shortcut)

    # Final Step: Add Shortcut Value to Main Path, and Pass It Through a RELU Activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

def ResidualNetwork(input_shape=(32, 32, 3), classes=10):
    # Define the Input As a Tensor with Shape Input_Shape
    X_input = Input(input_shape)

    # Stage 1
    X = Conv2D(64, (3, 3), padding='same')(X_input)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Stage 2
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])

    # Stage 3
    X = convolutional_block(X, filters=[32, 32, 128])
    X = identity_block(X, [32, 32, 128])
    X = identity_block(X, [32, 32, 128])
    X = identity_block(X, [32, 32, 128])
    X = identity_block(X, [32, 32, 128])
    X = identity_block(X, [32, 32, 128])
    X = identity_block(X, [32, 32, 128])
    X = identity_block(X, [32, 32, 128])

    # Stage 4
    X = convolutional_block(X, filters=[64, 64, 256])
    X = identity_block(X, [64, 64, 256])
    X = identity_block(X, [64, 64, 256])
    X = identity_block(X, [64, 64, 256])
    X = identity_block(X, [64, 64, 256])
    X = identity_block(X, [64, 64, 256])
    X = identity_block(X, [64, 64, 256])

    # Stage 5
    X = convolutional_block(X, filters=[128, 128, 512])
    X = identity_block(X, [128, 128, 512])
    X = identity_block(X, [128, 128, 512])
    X = identity_block(X, [128, 128, 512])
    X = identity_block(X, [128, 128, 512])
    X = identity_block(X, [128, 128, 512])

    # AVGPOOL
    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)

    # Output Layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax')(X)

    # Create Model
    ResNet_model = Model(inputs=X_input, outputs=X)
    
    return ResNet_model

ResNet = ResidualNetwork(input_shape = (32, 32, 3), classes = 10)

# Summary
ResNet.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_182 (Conv2D)            (None, 32, 32, 64)   1792        ['input_3[0][0]']
#
#  batch_normalization_182 (Batch  (None, 32, 32, 64)  256         ['conv2d_182[0][0]']
#  Normalization)
#
#  activation_176 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_182[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_176[0][0]']
#
#  batch_normalization_183 (Batch  (None, 32, 32, 16)  64          ['conv2d_183[0][0]']
#  Normalization)
#
#  activation_177 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_183[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_177[0][0]']
#
#  batch_normalization_184 (Batch  (None, 32, 32, 16)  64          ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_178 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_184[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_178[0][0]']
#
#  batch_normalization_185 (Batch  (None, 32, 32, 64)  256         ['conv2d_185[0][0]']
#  Normalization)
#
#  add_58 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_185[0][0]',
#                                                                   'activation_176[0][0]']
#
#  activation_179 (Activation)    (None, 32, 32, 64)   0           ['add_58[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_179[0][0]']
#
#  batch_normalization_186 (Batch  (None, 32, 32, 16)  64          ['conv2d_186[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_186[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_180[0][0]']
#
#  batch_normalization_187 (Batch  (None, 32, 32, 16)  64          ['conv2d_187[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_187[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_181[0][0]']
#
#  batch_normalization_188 (Batch  (None, 32, 32, 64)  256         ['conv2d_188[0][0]']
#  Normalization)
#
#  add_59 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_188[0][0]',
#                                                                   'activation_179[0][0]']
#
#  activation_182 (Activation)    (None, 32, 32, 64)   0           ['add_59[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_182[0][0]']
#
#  batch_normalization_189 (Batch  (None, 32, 32, 16)  64          ['conv2d_189[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_189[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_183[0][0]']
#
#  batch_normalization_190 (Batch  (None, 32, 32, 16)  64          ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_184 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_184[0][0]']
#
#  batch_normalization_191 (Batch  (None, 32, 32, 64)  256         ['conv2d_191[0][0]']
#  Normalization)
#
#  add_60 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_191[0][0]',
#                                                                   'activation_182[0][0]']
#
#  activation_185 (Activation)    (None, 32, 32, 64)   0           ['add_60[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_185[0][0]']
#
#  batch_normalization_192 (Batch  (None, 32, 32, 16)  64          ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_186 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_186[0][0]']
#
#  batch_normalization_193 (Batch  (None, 32, 32, 16)  64          ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_193[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_187[0][0]']
#
#  batch_normalization_194 (Batch  (None, 32, 32, 64)  256         ['conv2d_194[0][0]']
#  Normalization)
#
#  add_61 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_194[0][0]',
#                                                                   'activation_185[0][0]']
#
#  activation_188 (Activation)    (None, 32, 32, 64)   0           ['add_61[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_188[0][0]']
#
#  batch_normalization_195 (Batch  (None, 32, 32, 16)  64          ['conv2d_195[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_195[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_189[0][0]']
#
#  batch_normalization_196 (Batch  (None, 32, 32, 16)  64          ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_190 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_190[0][0]']
#
#  batch_normalization_197 (Batch  (None, 32, 32, 64)  256         ['conv2d_197[0][0]']
#  Normalization)
#
#  add_62 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_197[0][0]',
#                                                                   'activation_188[0][0]']
#
#  activation_191 (Activation)    (None, 32, 32, 64)   0           ['add_62[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_191[0][0]']
#
#  batch_normalization_198 (Batch  (None, 32, 32, 16)  64          ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_198[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_192[0][0]']
#
#  batch_normalization_199 (Batch  (None, 32, 32, 16)  64          ['conv2d_199[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_199[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_193[0][0]']
#
#  batch_normalization_200 (Batch  (None, 32, 32, 64)  256         ['conv2d_200[0][0]']
#  Normalization)
#
#  add_63 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_200[0][0]',
#                                                                   'activation_191[0][0]']
#
#  activation_194 (Activation)    (None, 32, 32, 64)   0           ['add_63[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_194[0][0]']
#
#  batch_normalization_201 (Batch  (None, 32, 32, 16)  64          ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_201[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_195[0][0]']
#
#  batch_normalization_202 (Batch  (None, 32, 32, 16)  64          ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_202[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_196[0][0]']
#
#  batch_normalization_203 (Batch  (None, 32, 32, 64)  256         ['conv2d_203[0][0]']
#  Normalization)
#
#  add_64 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_203[0][0]',
#                                                                   'activation_194[0][0]']
#
#  activation_197 (Activation)    (None, 32, 32, 64)   0           ['add_64[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 32, 32, 16)   1040        ['activation_197[0][0]']
#
#  batch_normalization_204 (Batch  (None, 32, 32, 16)  64          ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_198 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_204[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_198[0][0]']
#
#  batch_normalization_205 (Batch  (None, 32, 32, 16)  64          ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_205[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 32, 32, 64)   1088        ['activation_199[0][0]']
#
#  batch_normalization_206 (Batch  (None, 32, 32, 64)  256         ['conv2d_206[0][0]']
#  Normalization)
#
#  add_65 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_206[0][0]',
#                                                                   'activation_197[0][0]']
#
#  activation_200 (Activation)    (None, 32, 32, 64)   0           ['add_65[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 16, 16, 32)   2080        ['activation_200[0][0]']
#
#  batch_normalization_207 (Batch  (None, 16, 16, 32)  128         ['conv2d_207[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_207[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_201[0][0]']
#
#  batch_normalization_208 (Batch  (None, 16, 16, 32)  128         ['conv2d_208[0][0]']
#  Normalization)
#
#  activation_202 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_208[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 16, 16, 128)  4224        ['activation_202[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 16, 16, 128)  8320        ['activation_200[0][0]']
#
#  batch_normalization_209 (Batch  (None, 16, 16, 128)  512        ['conv2d_209[0][0]']
#  Normalization)
#
#  batch_normalization_210 (Batch  (None, 16, 16, 128)  512        ['conv2d_210[0][0]']
#  Normalization)
#
#  add_66 (Add)                   (None, 16, 16, 128)  0           ['batch_normalization_209[0][0]',
#                                                                   'batch_normalization_210[0][0]']
#
#  activation_203 (Activation)    (None, 16, 16, 128)  0           ['add_66[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 16, 16, 32)   4128        ['activation_203[0][0]']
#
#  batch_normalization_211 (Batch  (None, 16, 16, 32)  128         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_204 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_211[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_204[0][0]']
#
#  batch_normalization_212 (Batch  (None, 16, 16, 32)  128         ['conv2d_212[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_212[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 16, 16, 128)  4224        ['activation_205[0][0]']
#
#  batch_normalization_213 (Batch  (None, 16, 16, 128)  512        ['conv2d_213[0][0]']
#  Normalization)
#
#  add_67 (Add)                   (None, 16, 16, 128)  0           ['batch_normalization_213[0][0]',
#                                                                   'activation_203[0][0]']
#
#  activation_206 (Activation)    (None, 16, 16, 128)  0           ['add_67[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 16, 16, 32)   4128        ['activation_206[0][0]']
#
#  batch_normalization_214 (Batch  (None, 16, 16, 32)  128         ['conv2d_214[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_214[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_207[0][0]']
#
#  batch_normalization_215 (Batch  (None, 16, 16, 32)  128         ['conv2d_215[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_215[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 16, 16, 128)  4224        ['activation_208[0][0]']
#
#  batch_normalization_216 (Batch  (None, 16, 16, 128)  512        ['conv2d_216[0][0]']
#  Normalization)
#
#  add_68 (Add)                   (None, 16, 16, 128)  0           ['batch_normalization_216[0][0]',
#                                                                   'activation_206[0][0]']
#
#  activation_209 (Activation)    (None, 16, 16, 128)  0           ['add_68[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 16, 16, 32)   4128        ['activation_209[0][0]']
#
#  batch_normalization_217 (Batch  (None, 16, 16, 32)  128         ['conv2d_217[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_217[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_210[0][0]']
#
#  batch_normalization_218 (Batch  (None, 16, 16, 32)  128         ['conv2d_218[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_218[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 16, 16, 128)  4224        ['activation_211[0][0]']
#
#  batch_normalization_219 (Batch  (None, 16, 16, 128)  512        ['conv2d_219[0][0]']
#  Normalization)
#
#  add_69 (Add)                   (None, 16, 16, 128)  0           ['batch_normalization_219[0][0]',
#                                                                   'activation_209[0][0]']
#
#  activation_212 (Activation)    (None, 16, 16, 128)  0           ['add_69[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 16, 16, 32)   4128        ['activation_212[0][0]']
#
#  batch_normalization_220 (Batch  (None, 16, 16, 32)  128         ['conv2d_220[0][0]']
#  Normalization)
#
#  activation_213 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_220[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_213[0][0]']
#
#  batch_normalization_221 (Batch  (None, 16, 16, 32)  128         ['conv2d_221[0][0]']
#  Normalization)
#
#  activation_214 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_221[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 16, 16, 128)  4224        ['activation_214[0][0]']
#
#  batch_normalization_222 (Batch  (None, 16, 16, 128)  512        ['conv2d_222[0][0]']
#  Normalization)
#
#  add_70 (Add)                   (None, 16, 16, 128)  0           ['batch_normalization_222[0][0]',
#                                                                   'activation_212[0][0]']
#
#  activation_215 (Activation)    (None, 16, 16, 128)  0           ['add_70[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 16, 16, 32)   4128        ['activation_215[0][0]']
#
#  batch_normalization_223 (Batch  (None, 16, 16, 32)  128         ['conv2d_223[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_223[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_216[0][0]']
#
#  batch_normalization_224 (Batch  (None, 16, 16, 32)  128         ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_217 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_224[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 16, 16, 128)  4224        ['activation_217[0][0]']
#
#  batch_normalization_225 (Batch  (None, 16, 16, 128)  512        ['conv2d_225[0][0]']
#  Normalization)
#
#  add_71 (Add)                   (None, 16, 16, 128)  0           ['batch_normalization_225[0][0]',
#                                                                   'activation_215[0][0]']
#
#  activation_218 (Activation)    (None, 16, 16, 128)  0           ['add_71[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 16, 16, 32)   4128        ['activation_218[0][0]']
#
#  batch_normalization_226 (Batch  (None, 16, 16, 32)  128         ['conv2d_226[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_226[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_219[0][0]']
#
#  batch_normalization_227 (Batch  (None, 16, 16, 32)  128         ['conv2d_227[0][0]']
#  Normalization)
#
#  activation_220 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_227[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 16, 16, 128)  4224        ['activation_220[0][0]']
#
#  batch_normalization_228 (Batch  (None, 16, 16, 128)  512        ['conv2d_228[0][0]']
#  Normalization)
#
#  add_72 (Add)                   (None, 16, 16, 128)  0           ['batch_normalization_228[0][0]',
#                                                                   'activation_218[0][0]']
#
#  activation_221 (Activation)    (None, 16, 16, 128)  0           ['add_72[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 16, 16, 32)   4128        ['activation_221[0][0]']
#
#  batch_normalization_229 (Batch  (None, 16, 16, 32)  128         ['conv2d_229[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_229[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_222[0][0]']
#
#  batch_normalization_230 (Batch  (None, 16, 16, 32)  128         ['conv2d_230[0][0]']
#  Normalization)
#
#  activation_223 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_230[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 16, 16, 128)  4224        ['activation_223[0][0]']
#
#  batch_normalization_231 (Batch  (None, 16, 16, 128)  512        ['conv2d_231[0][0]']
#  Normalization)
#
#  add_73 (Add)                   (None, 16, 16, 128)  0           ['batch_normalization_231[0][0]',
#                                                                   'activation_221[0][0]']
#
#  activation_224 (Activation)    (None, 16, 16, 128)  0           ['add_73[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 8, 8, 64)     8256        ['activation_224[0][0]']
#
#  batch_normalization_232 (Batch  (None, 8, 8, 64)    256         ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_225 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_232[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_225[0][0]']
#
#  batch_normalization_233 (Batch  (None, 8, 8, 64)    256         ['conv2d_233[0][0]']
#  Normalization)
#
#  activation_226 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_233[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 8, 8, 256)    16640       ['activation_226[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 8, 8, 256)    33024       ['activation_224[0][0]']
#
#  batch_normalization_234 (Batch  (None, 8, 8, 256)   1024        ['conv2d_234[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 8, 8, 256)   1024        ['conv2d_235[0][0]']
#  Normalization)
#
#  add_74 (Add)                   (None, 8, 8, 256)    0           ['batch_normalization_234[0][0]',
#                                                                   'batch_normalization_235[0][0]']
#
#  activation_227 (Activation)    (None, 8, 8, 256)    0           ['add_74[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 8, 8, 64)     16448       ['activation_227[0][0]']
#
#  batch_normalization_236 (Batch  (None, 8, 8, 64)    256         ['conv2d_236[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_236[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_228[0][0]']
#
#  batch_normalization_237 (Batch  (None, 8, 8, 64)    256         ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_229 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_237[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 8, 8, 256)    16640       ['activation_229[0][0]']
#
#  batch_normalization_238 (Batch  (None, 8, 8, 256)   1024        ['conv2d_238[0][0]']
#  Normalization)
#
#  add_75 (Add)                   (None, 8, 8, 256)    0           ['batch_normalization_238[0][0]',
#                                                                   'activation_227[0][0]']
#
#  activation_230 (Activation)    (None, 8, 8, 256)    0           ['add_75[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 8, 8, 64)     16448       ['activation_230[0][0]']
#
#  batch_normalization_239 (Batch  (None, 8, 8, 64)    256         ['conv2d_239[0][0]']
#  Normalization)
#
#  activation_231 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_239[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_231[0][0]']
#
#  batch_normalization_240 (Batch  (None, 8, 8, 64)    256         ['conv2d_240[0][0]']
#  Normalization)
#
#  activation_232 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_240[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 8, 8, 256)    16640       ['activation_232[0][0]']
#
#  batch_normalization_241 (Batch  (None, 8, 8, 256)   1024        ['conv2d_241[0][0]']
#  Normalization)
#
#  add_76 (Add)                   (None, 8, 8, 256)    0           ['batch_normalization_241[0][0]',
#                                                                   'activation_230[0][0]']
#
#  activation_233 (Activation)    (None, 8, 8, 256)    0           ['add_76[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 8, 8, 64)     16448       ['activation_233[0][0]']
#
#  batch_normalization_242 (Batch  (None, 8, 8, 64)    256         ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_242[0][0]']
# ...
#  activation_245 (Activation)    (None, 8, 8, 256)    0           ['add_80[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 4, 4, 128)    32896       ['activation_245[0][0]']
#
#  batch_normalization_254 (Batch  (None, 4, 4, 128)   512         ['conv2d_254[0][0]']
#  Normalization)
#
#  activation_246 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_254[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_246[0][0]']
#
#  batch_normalization_255 (Batch  (None, 4, 4, 128)   512         ['conv2d_255[0][0]']
#  Normalization)
#
#  activation_247 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_255[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 4, 4, 512)    66048       ['activation_247[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 4, 4, 512)    131584      ['activation_245[0][0]']
#
#  batch_normalization_256 (Batch  (None, 4, 4, 512)   2048        ['conv2d_256[0][0]']
#  Normalization)
#
#  batch_normalization_257 (Batch  (None, 4, 4, 512)   2048        ['conv2d_257[0][0]']
#  Normalization)
#
#  add_81 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_256[0][0]',
#                                                                   'batch_normalization_257[0][0]']
#
#  activation_248 (Activation)    (None, 4, 4, 512)    0           ['add_81[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 4, 4, 128)    65664       ['activation_248[0][0]']
#
#  batch_normalization_258 (Batch  (None, 4, 4, 128)   512         ['conv2d_258[0][0]']
#  Normalization)
#
#  activation_249 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_258[0][0]']
#
#  conv2d_259 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_249[0][0]']
#
#  batch_normalization_259 (Batch  (None, 4, 4, 128)   512         ['conv2d_259[0][0]']
#  Normalization)
#
#  activation_250 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_259[0][0]']
#
#  conv2d_260 (Conv2D)            (None, 4, 4, 512)    66048       ['activation_250[0][0]']
#
#  batch_normalization_260 (Batch  (None, 4, 4, 512)   2048        ['conv2d_260[0][0]']
#  Normalization)
#
#  add_82 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_260[0][0]',
#                                                                   'activation_248[0][0]']
#
#  activation_251 (Activation)    (None, 4, 4, 512)    0           ['add_82[0][0]']
#
#  conv2d_261 (Conv2D)            (None, 4, 4, 128)    65664       ['activation_251[0][0]']
#
#  batch_normalization_261 (Batch  (None, 4, 4, 128)   512         ['conv2d_261[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_261[0][0]']
#
#  conv2d_262 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_252[0][0]']
#
#  batch_normalization_262 (Batch  (None, 4, 4, 128)   512         ['conv2d_262[0][0]']
#  Normalization)
#
#  activation_253 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_262[0][0]']
#
#  conv2d_263 (Conv2D)            (None, 4, 4, 512)    66048       ['activation_253[0][0]']
#
#  batch_normalization_263 (Batch  (None, 4, 4, 512)   2048        ['conv2d_263[0][0]']
#  Normalization)
#
#  add_83 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_263[0][0]',
#                                                                   'activation_251[0][0]']
#
#  activation_254 (Activation)    (None, 4, 4, 512)    0           ['add_83[0][0]']
#
#  conv2d_264 (Conv2D)            (None, 4, 4, 128)    65664       ['activation_254[0][0]']
#
#  batch_normalization_264 (Batch  (None, 4, 4, 128)   512         ['conv2d_264[0][0]']
#  Normalization)
#
#  activation_255 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_264[0][0]']
#
#  conv2d_265 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_255[0][0]']
#
#  batch_normalization_265 (Batch  (None, 4, 4, 128)   512         ['conv2d_265[0][0]']
#  Normalization)
#
#  activation_256 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_265[0][0]']
#
#  conv2d_266 (Conv2D)            (None, 4, 4, 512)    66048       ['activation_256[0][0]']
#
#  batch_normalization_266 (Batch  (None, 4, 4, 512)   2048        ['conv2d_266[0][0]']
#  Normalization)
#
#  add_84 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_266[0][0]',
#                                                                   'activation_254[0][0]']
#
#  activation_257 (Activation)    (None, 4, 4, 512)    0           ['add_84[0][0]']
#
#  conv2d_267 (Conv2D)            (None, 4, 4, 128)    65664       ['activation_257[0][0]']
#
#  batch_normalization_267 (Batch  (None, 4, 4, 128)   512         ['conv2d_267[0][0]']
#  Normalization)
#
#  activation_258 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_267[0][0]']
#
#  conv2d_268 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_258[0][0]']
#
#  batch_normalization_268 (Batch  (None, 4, 4, 128)   512         ['conv2d_268[0][0]']
#  Normalization)
#
#  activation_259 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_268[0][0]']
#
#  conv2d_269 (Conv2D)            (None, 4, 4, 512)    66048       ['activation_259[0][0]']
#
#  batch_normalization_269 (Batch  (None, 4, 4, 512)   2048        ['conv2d_269[0][0]']
#  Normalization)
#
#  add_85 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_269[0][0]',
#                                                                   'activation_257[0][0]']
#
#  activation_260 (Activation)    (None, 4, 4, 512)    0           ['add_85[0][0]']
#
#  conv2d_270 (Conv2D)            (None, 4, 4, 128)    65664       ['activation_260[0][0]']
#
#  batch_normalization_270 (Batch  (None, 4, 4, 128)   512         ['conv2d_270[0][0]']
#  Normalization)
#
#  activation_261 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_270[0][0]']
#
#  conv2d_271 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_261[0][0]']
#
#  batch_normalization_271 (Batch  (None, 4, 4, 128)   512         ['conv2d_271[0][0]']
#  Normalization)
#
#  activation_262 (Activation)    (None, 4, 4, 128)    0           ['batch_normalization_271[0][0]']
#
#  conv2d_272 (Conv2D)            (None, 4, 4, 512)    66048       ['activation_262[0][0]']
#
#  batch_normalization_272 (Batch  (None, 4, 4, 512)   2048        ['conv2d_272[0][0]']
#  Normalization)
#
#  add_86 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_272[0][0]',
#                                                                   'activation_260[0][0]']
#
#  activation_263 (Activation)    (None, 4, 4, 512)    0           ['add_86[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 2, 2, 512)   0           ['activation_263[0][0]']
#  oling2D)
#
#  flatten_2 (Flatten)            (None, 2048)         0           ['average_pooling2d_2[0][0]']
#
#  dense_2 (Dense)                (None, 10)           20490       ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 2,536,714
# Trainable params: 2,515,594
# Non-trainable params: 21,120
# __________________________________________________________________________________________________

# %%
# Learning Rate Scheduler
def scheduler(epoch, lr):
    if epoch < 80:
        return lr
    else:
        return lr * tf.math.exp(-0.1)
    
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
# Train ResNet Model
ResNet.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
img_gen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, rotation_range=10, horizontal_flip=True, zoom_range=0.1)
img_gen.fit(x_train_norm)
train_history = ResNet.fit(img_gen.flow(x_train_norm, y_TrainOneHot, batch_size=32), steps_per_epoch=1500, epochs=150, callbacks=[callback], shuffle=True, validation_data = (x_test_norm, y_TestOneHot), verbose=1)
# Out:
# Epoch 1/150
# 1500/1500 [==============================] - 83s 50ms/step - loss: 2.1384 - accuracy: 0.2908 - val_loss: 1.7556 - val_accuracy: 0.3995 - lr: 0.0010
# Epoch 2/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 1.5894 - accuracy: 0.4308 - val_loss: 1.7452 - val_accuracy: 0.4501 - lr: 0.0010
# Epoch 3/150
# 1500/1500 [==============================] - 73s 49ms/step - loss: 1.4176 - accuracy: 0.4957 - val_loss: 1.4311 - val_accuracy: 0.5111 - lr: 0.0010
# Epoch 4/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 1.2522 - accuracy: 0.5557 - val_loss: 1.1568 - val_accuracy: 0.5842 - lr: 0.0010
# Epoch 5/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 1.1147 - accuracy: 0.6099 - val_loss: 1.3148 - val_accuracy: 0.5822 - lr: 0.0010
# Epoch 6/150
# 1500/1500 [==============================] - 73s 48ms/step - loss: 0.9923 - accuracy: 0.6517 - val_loss: 1.0422 - val_accuracy: 0.6516 - lr: 0.0010
# Epoch 7/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.8878 - accuracy: 0.6900 - val_loss: 0.9306 - val_accuracy: 0.6871 - lr: 0.0010
# Epoch 8/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.8019 - accuracy: 0.7213 - val_loss: 0.7851 - val_accuracy: 0.7290 - lr: 0.0010
# Epoch 9/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.7209 - accuracy: 0.7485 - val_loss: 0.8272 - val_accuracy: 0.7239 - lr: 0.0010
# Epoch 10/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.6765 - accuracy: 0.7637 - val_loss: 0.9490 - val_accuracy: 0.7060 - lr: 0.0010
# Epoch 11/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.6303 - accuracy: 0.7817 - val_loss: 0.8170 - val_accuracy: 0.7476 - lr: 0.0010
# Epoch 12/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.5912 - accuracy: 0.7941 - val_loss: 0.6845 - val_accuracy: 0.7764 - lr: 0.0010
# Epoch 13/150
# 1500/1500 [==============================] - 70s 47ms/step - loss: 0.5600 - accuracy: 0.8060 - val_loss: 0.6196 - val_accuracy: 0.7929 - lr: 0.0010
# Epoch 14/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.5416 - accuracy: 0.8112 - val_loss: 0.6081 - val_accuracy: 0.8047 - lr: 0.0010
# Epoch 15/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.5079 - accuracy: 0.8252 - val_loss: 0.5904 - val_accuracy: 0.8071 - lr: 0.0010
# Epoch 16/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.4872 - accuracy: 0.8285 - val_loss: 0.5533 - val_accuracy: 0.8150 - lr: 0.0010
# Epoch 17/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.4708 - accuracy: 0.8354 - val_loss: 0.4955 - val_accuracy: 0.8369 - lr: 0.0010
# Epoch 18/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.4417 - accuracy: 0.8464 - val_loss: 0.7560 - val_accuracy: 0.7674 - lr: 0.0010
# Epoch 19/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.4316 - accuracy: 0.8499 - val_loss: 0.8159 - val_accuracy: 0.7982 - lr: 0.0010
# Epoch 20/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.4155 - accuracy: 0.8555 - val_loss: 0.5775 - val_accuracy: 0.8141 - lr: 0.0010
# Epoch 21/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.3953 - accuracy: 0.8617 - val_loss: 0.6483 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 22/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.3877 - accuracy: 0.8649 - val_loss: 0.5513 - val_accuracy: 0.8199 - lr: 0.0010
# Epoch 23/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.3674 - accuracy: 0.8719 - val_loss: 0.4813 - val_accuracy: 0.8413 - lr: 0.0010
# Epoch 24/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.3563 - accuracy: 0.8761 - val_loss: 0.5689 - val_accuracy: 0.8223 - lr: 0.0010
# Epoch 25/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.3442 - accuracy: 0.8796 - val_loss: 0.5269 - val_accuracy: 0.8335 - lr: 0.0010
# Epoch 26/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.3402 - accuracy: 0.8807 - val_loss: 0.6891 - val_accuracy: 0.8044 - lr: 0.0010
# Epoch 27/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.3260 - accuracy: 0.8857 - val_loss: 0.5621 - val_accuracy: 0.8270 - lr: 0.0010
# Epoch 28/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.3211 - accuracy: 0.8876 - val_loss: 0.7029 - val_accuracy: 0.8129 - lr: 0.0010
# Epoch 29/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.3161 - accuracy: 0.8887 - val_loss: 0.5189 - val_accuracy: 0.8390 - lr: 0.0010
# Epoch 30/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.3005 - accuracy: 0.8947 - val_loss: 0.6348 - val_accuracy: 0.8114 - lr: 0.0010
# Epoch 31/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2963 - accuracy: 0.8977 - val_loss: 0.5110 - val_accuracy: 0.8444 - lr: 0.0010
# Epoch 32/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2896 - accuracy: 0.8978 - val_loss: 0.4157 - val_accuracy: 0.8658 - lr: 0.0010
# Epoch 33/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2725 - accuracy: 0.9031 - val_loss: 0.4457 - val_accuracy: 0.8637 - lr: 0.0010
# Epoch 34/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2750 - accuracy: 0.9048 - val_loss: 0.4665 - val_accuracy: 0.8572 - lr: 0.0010
# Epoch 35/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2671 - accuracy: 0.9060 - val_loss: 0.4972 - val_accuracy: 0.8559 - lr: 0.0010
# Epoch 36/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2604 - accuracy: 0.9096 - val_loss: 0.4742 - val_accuracy: 0.8529 - lr: 0.0010
# Epoch 37/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2532 - accuracy: 0.9107 - val_loss: 0.3993 - val_accuracy: 0.8748 - lr: 0.0010
# Epoch 38/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.2523 - accuracy: 0.9108 - val_loss: 0.7868 - val_accuracy: 0.8383 - lr: 0.0010
# Epoch 39/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.2445 - accuracy: 0.9136 - val_loss: 0.4996 - val_accuracy: 0.8630 - lr: 0.0010
# Epoch 40/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2414 - accuracy: 0.9148 - val_loss: 0.5287 - val_accuracy: 0.8474 - lr: 0.0010
# Epoch 41/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2319 - accuracy: 0.9169 - val_loss: 0.4449 - val_accuracy: 0.8631 - lr: 0.0010
# Epoch 42/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2301 - accuracy: 0.9199 - val_loss: 0.4518 - val_accuracy: 0.8670 - lr: 0.0010
# Epoch 43/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2289 - accuracy: 0.9207 - val_loss: 0.9300 - val_accuracy: 0.8420 - lr: 0.0010
# Epoch 44/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.2198 - accuracy: 0.9231 - val_loss: 0.4554 - val_accuracy: 0.8650 - lr: 0.0010
# Epoch 45/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.2251 - accuracy: 0.9201 - val_loss: 0.4651 - val_accuracy: 0.8692 - lr: 0.0010
# Epoch 46/150
# 1500/1500 [==============================] - 73s 48ms/step - loss: 0.2113 - accuracy: 0.9251 - val_loss: 0.3620 - val_accuracy: 0.8894 - lr: 0.0010
# Epoch 47/150
# 1500/1500 [==============================] - 73s 48ms/step - loss: 0.2077 - accuracy: 0.9254 - val_loss: 0.3902 - val_accuracy: 0.8809 - lr: 0.0010
# Epoch 48/150
# 1500/1500 [==============================] - 73s 48ms/step - loss: 0.2006 - accuracy: 0.9281 - val_loss: 0.7729 - val_accuracy: 0.8065 - lr: 0.0010
# Epoch 49/150
# 1500/1500 [==============================] - 73s 48ms/step - loss: 0.1975 - accuracy: 0.9303 - val_loss: 0.4224 - val_accuracy: 0.8812 - lr: 0.0010
# Epoch 50/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1972 - accuracy: 0.9313 - val_loss: 0.4955 - val_accuracy: 0.8633 - lr: 0.0010
# Epoch 51/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.1934 - accuracy: 0.9318 - val_loss: 0.4053 - val_accuracy: 0.8799 - lr: 0.0010
# Epoch 52/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1870 - accuracy: 0.9342 - val_loss: 0.4590 - val_accuracy: 0.8689 - lr: 0.0010
# Epoch 53/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1909 - accuracy: 0.9329 - val_loss: 0.5223 - val_accuracy: 0.8530 - lr: 0.0010
# Epoch 54/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1818 - accuracy: 0.9345 - val_loss: 0.6376 - val_accuracy: 0.8650 - lr: 0.0010
# Epoch 55/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.1871 - accuracy: 0.9324 - val_loss: 0.5579 - val_accuracy: 0.8445 - lr: 0.0010
# Epoch 56/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1779 - accuracy: 0.9364 - val_loss: 0.3874 - val_accuracy: 0.8887 - lr: 0.0010
# Epoch 57/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.1639 - accuracy: 0.9426 - val_loss: 0.3738 - val_accuracy: 0.8899 - lr: 0.0010
# Epoch 58/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.1669 - accuracy: 0.9428 - val_loss: 0.5716 - val_accuracy: 0.8521 - lr: 0.0010
# Epoch 59/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.1648 - accuracy: 0.9428 - val_loss: 0.5754 - val_accuracy: 0.8502 - lr: 0.0010
# Epoch 60/150
# 1500/1500 [==============================] - 70s 47ms/step - loss: 0.1631 - accuracy: 0.9422 - val_loss: 0.4788 - val_accuracy: 0.8698 - lr: 0.0010
# Epoch 61/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.1583 - accuracy: 0.9442 - val_loss: 0.4725 - val_accuracy: 0.8710 - lr: 0.0010
# Epoch 62/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.1623 - accuracy: 0.9439 - val_loss: 0.4173 - val_accuracy: 0.8838 - lr: 0.0010
# Epoch 63/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1602 - accuracy: 0.9433 - val_loss: 0.4567 - val_accuracy: 0.8804 - lr: 0.0010
# Epoch 64/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1536 - accuracy: 0.9466 - val_loss: 0.5190 - val_accuracy: 0.8726 - lr: 0.0010
# Epoch 65/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1577 - accuracy: 0.9441 - val_loss: 0.9416 - val_accuracy: 0.8512 - lr: 0.0010
# Epoch 66/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1513 - accuracy: 0.9473 - val_loss: 0.4687 - val_accuracy: 0.8769 - lr: 0.0010
# Epoch 67/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1488 - accuracy: 0.9485 - val_loss: 0.5247 - val_accuracy: 0.8650 - lr: 0.0010
# Epoch 68/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1429 - accuracy: 0.9502 - val_loss: 0.4959 - val_accuracy: 0.8784 - lr: 0.0010
# Epoch 69/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1428 - accuracy: 0.9507 - val_loss: 0.4963 - val_accuracy: 0.8757 - lr: 0.0010
# Epoch 70/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1425 - accuracy: 0.9500 - val_loss: 0.4985 - val_accuracy: 0.8721 - lr: 0.0010
# Epoch 71/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1438 - accuracy: 0.9491 - val_loss: 0.4602 - val_accuracy: 0.8794 - lr: 0.0010
# Epoch 72/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1376 - accuracy: 0.9517 - val_loss: 0.7346 - val_accuracy: 0.8641 - lr: 0.0010
# Epoch 73/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1421 - accuracy: 0.9498 - val_loss: 0.4605 - val_accuracy: 0.8822 - lr: 0.0010
# Epoch 74/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1384 - accuracy: 0.9513 - val_loss: 0.4291 - val_accuracy: 0.8792 - lr: 0.0010
# Epoch 75/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1340 - accuracy: 0.9536 - val_loss: 0.4054 - val_accuracy: 0.8885 - lr: 0.0010
# Epoch 76/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1304 - accuracy: 0.9543 - val_loss: 0.4856 - val_accuracy: 0.8759 - lr: 0.0010
# Epoch 77/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1310 - accuracy: 0.9533 - val_loss: 0.4324 - val_accuracy: 0.8859 - lr: 0.0010
# Epoch 78/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.1259 - accuracy: 0.9555 - val_loss: 0.6244 - val_accuracy: 0.8509 - lr: 0.0010
# Epoch 79/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.1267 - accuracy: 0.9555 - val_loss: 0.4892 - val_accuracy: 0.8802 - lr: 0.0010
# Epoch 80/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.1278 - accuracy: 0.9548 - val_loss: 0.5815 - val_accuracy: 0.8635 - lr: 0.0010
# Epoch 81/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.1160 - accuracy: 0.9585 - val_loss: 0.4786 - val_accuracy: 0.8793 - lr: 9.0484e-04
# Epoch 82/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.1070 - accuracy: 0.9628 - val_loss: 0.4392 - val_accuracy: 0.8858 - lr: 8.1873e-04
# Epoch 83/150
# 1500/1500 [==============================] - 73s 49ms/step - loss: 0.0971 - accuracy: 0.9666 - val_loss: 0.4250 - val_accuracy: 0.8927 - lr: 7.4082e-04
# Epoch 84/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0905 - accuracy: 0.9679 - val_loss: 0.3803 - val_accuracy: 0.9017 - lr: 6.7032e-04
# Epoch 85/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0838 - accuracy: 0.9703 - val_loss: 0.4234 - val_accuracy: 0.8955 - lr: 6.0653e-04
# Epoch 86/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0739 - accuracy: 0.9733 - val_loss: 0.4372 - val_accuracy: 0.8942 - lr: 5.4881e-04
# Epoch 87/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0698 - accuracy: 0.9761 - val_loss: 0.4546 - val_accuracy: 0.8921 - lr: 4.9659e-04
# Epoch 88/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0672 - accuracy: 0.9764 - val_loss: 0.4106 - val_accuracy: 0.9004 - lr: 4.4933e-04
# Epoch 89/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0620 - accuracy: 0.9781 - val_loss: 0.4227 - val_accuracy: 0.9004 - lr: 4.0657e-04
# Epoch 90/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.0577 - accuracy: 0.9802 - val_loss: 0.4221 - val_accuracy: 0.9001 - lr: 3.6788e-04
# Epoch 91/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0528 - accuracy: 0.9810 - val_loss: 0.4182 - val_accuracy: 0.9029 - lr: 3.3287e-04
# Epoch 92/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.0491 - accuracy: 0.9821 - val_loss: 0.3984 - val_accuracy: 0.9076 - lr: 3.0119e-04
# Epoch 93/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.0474 - accuracy: 0.9836 - val_loss: 0.3918 - val_accuracy: 0.9109 - lr: 2.7253e-04
# Epoch 94/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0430 - accuracy: 0.9853 - val_loss: 0.4046 - val_accuracy: 0.9082 - lr: 2.4660e-04
# Epoch 95/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0415 - accuracy: 0.9857 - val_loss: 0.4368 - val_accuracy: 0.9051 - lr: 2.2313e-04
# Epoch 96/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0394 - accuracy: 0.9862 - val_loss: 0.3866 - val_accuracy: 0.9106 - lr: 2.0190e-04
# Epoch 97/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0374 - accuracy: 0.9867 - val_loss: 0.4270 - val_accuracy: 0.9051 - lr: 1.8268e-04
# Epoch 98/150
# 1500/1500 [==============================] - 70s 47ms/step - loss: 0.0354 - accuracy: 0.9878 - val_loss: 0.4305 - val_accuracy: 0.9056 - lr: 1.6530e-04
# Epoch 99/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0344 - accuracy: 0.9880 - val_loss: 0.4120 - val_accuracy: 0.9091 - lr: 1.4957e-04
# Epoch 100/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0331 - accuracy: 0.9885 - val_loss: 0.4240 - val_accuracy: 0.9070 - lr: 1.3534e-04
# Epoch 101/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.0326 - accuracy: 0.9891 - val_loss: 0.4258 - val_accuracy: 0.9072 - lr: 1.2246e-04
# Epoch 102/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0314 - accuracy: 0.9899 - val_loss: 0.4215 - val_accuracy: 0.9097 - lr: 1.1080e-04
# Epoch 103/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.0301 - accuracy: 0.9893 - val_loss: 0.4177 - val_accuracy: 0.9123 - lr: 1.0026e-04
# Epoch 104/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.0287 - accuracy: 0.9898 - val_loss: 0.4192 - val_accuracy: 0.9100 - lr: 9.0718e-05
# Epoch 105/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0285 - accuracy: 0.9900 - val_loss: 0.4197 - val_accuracy: 0.9102 - lr: 8.2085e-05
# Epoch 106/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.0274 - accuracy: 0.9903 - val_loss: 0.4172 - val_accuracy: 0.9113 - lr: 7.4273e-05
# Epoch 107/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0264 - accuracy: 0.9914 - val_loss: 0.4283 - val_accuracy: 0.9120 - lr: 6.7205e-05
# Epoch 108/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.0257 - accuracy: 0.9911 - val_loss: 0.4235 - val_accuracy: 0.9120 - lr: 6.0810e-05
# Epoch 109/150
# 1500/1500 [==============================] - 71s 48ms/step - loss: 0.0260 - accuracy: 0.9914 - val_loss: 0.4248 - val_accuracy: 0.9119 - lr: 5.5023e-05
# Epoch 110/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0250 - accuracy: 0.9912 - val_loss: 0.4173 - val_accuracy: 0.9118 - lr: 4.9787e-05
# Epoch 111/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0263 - accuracy: 0.9907 - val_loss: 0.4172 - val_accuracy: 0.9138 - lr: 4.5049e-05
# Epoch 112/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0242 - accuracy: 0.9917 - val_loss: 0.4169 - val_accuracy: 0.9133 - lr: 4.0762e-05
# Epoch 113/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0245 - accuracy: 0.9916 - val_loss: 0.4204 - val_accuracy: 0.9119 - lr: 3.6883e-05
# Epoch 114/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0222 - accuracy: 0.9925 - val_loss: 0.4217 - val_accuracy: 0.9116 - lr: 3.3373e-05
# Epoch 115/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0242 - accuracy: 0.9919 - val_loss: 0.4224 - val_accuracy: 0.9107 - lr: 3.0197e-05
# Epoch 116/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0233 - accuracy: 0.9922 - val_loss: 0.4246 - val_accuracy: 0.9107 - lr: 2.7324e-05
# Epoch 117/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0239 - accuracy: 0.9919 - val_loss: 0.4233 - val_accuracy: 0.9105 - lr: 2.4723e-05
# Epoch 118/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0230 - accuracy: 0.9924 - val_loss: 0.4273 - val_accuracy: 0.9098 - lr: 2.2371e-05
# Epoch 119/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0226 - accuracy: 0.9923 - val_loss: 0.4269 - val_accuracy: 0.9101 - lr: 2.0242e-05
# Epoch 120/150
# 1500/1500 [==============================] - 73s 48ms/step - loss: 0.0210 - accuracy: 0.9931 - val_loss: 0.4288 - val_accuracy: 0.9101 - lr: 1.8316e-05
# Epoch 121/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0212 - accuracy: 0.9927 - val_loss: 0.4304 - val_accuracy: 0.9105 - lr: 1.6573e-05
# Epoch 122/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0219 - accuracy: 0.9926 - val_loss: 0.4218 - val_accuracy: 0.9117 - lr: 1.4996e-05
# Epoch 123/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0207 - accuracy: 0.9930 - val_loss: 0.4307 - val_accuracy: 0.9114 - lr: 1.3569e-05
# Epoch 124/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 0.4232 - val_accuracy: 0.9120 - lr: 1.2277e-05
# Epoch 125/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0207 - accuracy: 0.9930 - val_loss: 0.4280 - val_accuracy: 0.9107 - lr: 1.1109e-05
# Epoch 126/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0220 - accuracy: 0.9924 - val_loss: 0.4225 - val_accuracy: 0.9126 - lr: 1.0052e-05
# Epoch 127/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0226 - accuracy: 0.9923 - val_loss: 0.4263 - val_accuracy: 0.9115 - lr: 9.0953e-06
# Epoch 128/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0218 - accuracy: 0.9924 - val_loss: 0.4235 - val_accuracy: 0.9119 - lr: 8.2297e-06
# Epoch 129/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0227 - accuracy: 0.9927 - val_loss: 0.4229 - val_accuracy: 0.9118 - lr: 7.4466e-06
# Epoch 130/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0201 - accuracy: 0.9928 - val_loss: 0.4236 - val_accuracy: 0.9111 - lr: 6.7379e-06
# Epoch 131/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0201 - accuracy: 0.9933 - val_loss: 0.4271 - val_accuracy: 0.9122 - lr: 6.0967e-06
# Epoch 132/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0212 - accuracy: 0.9930 - val_loss: 0.4267 - val_accuracy: 0.9118 - lr: 5.5165e-06
# Epoch 133/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.4259 - val_accuracy: 0.9120 - lr: 4.9916e-06
# Epoch 134/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0206 - accuracy: 0.9930 - val_loss: 0.4283 - val_accuracy: 0.9117 - lr: 4.5166e-06
# Epoch 135/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0203 - accuracy: 0.9931 - val_loss: 0.4262 - val_accuracy: 0.9114 - lr: 4.0868e-06
# Epoch 136/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0208 - accuracy: 0.9928 - val_loss: 0.4277 - val_accuracy: 0.9111 - lr: 3.6979e-06
# Epoch 137/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0212 - accuracy: 0.9930 - val_loss: 0.4254 - val_accuracy: 0.9118 - lr: 3.3460e-06
# Epoch 138/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0229 - accuracy: 0.9920 - val_loss: 0.4256 - val_accuracy: 0.9122 - lr: 3.0275e-06
# Epoch 139/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0219 - accuracy: 0.9928 - val_loss: 0.4263 - val_accuracy: 0.9128 - lr: 2.7394e-06
# Epoch 140/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0204 - accuracy: 0.9935 - val_loss: 0.4253 - val_accuracy: 0.9129 - lr: 2.4787e-06
# Epoch 141/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0216 - accuracy: 0.9930 - val_loss: 0.4268 - val_accuracy: 0.9124 - lr: 2.2429e-06
# Epoch 142/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0200 - accuracy: 0.9936 - val_loss: 0.4248 - val_accuracy: 0.9128 - lr: 2.0294e-06
# Epoch 143/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 0.4231 - val_accuracy: 0.9123 - lr: 1.8363e-06
# Epoch 144/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 0.0205 - accuracy: 0.9931 - val_loss: 0.4280 - val_accuracy: 0.9120 - lr: 1.6616e-06
# Epoch 145/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0196 - accuracy: 0.9935 - val_loss: 0.4296 - val_accuracy: 0.9119 - lr: 1.5034e-06
# Epoch 146/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0199 - accuracy: 0.9930 - val_loss: 0.4287 - val_accuracy: 0.9125 - lr: 1.3604e-06
# Epoch 147/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0213 - accuracy: 0.9931 - val_loss: 0.4249 - val_accuracy: 0.9120 - lr: 1.2309e-06
# Epoch 148/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.4285 - val_accuracy: 0.9124 - lr: 1.1138e-06
# Epoch 149/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.0201 - accuracy: 0.9934 - val_loss: 0.4299 - val_accuracy: 0.9118 - lr: 1.0078e-06
# Epoch 150/150
# 1500/1500 [==============================] - 70s 47ms/step - loss: 0.0215 - accuracy: 0.9922 - val_loss: 0.4243 - val_accuracy: 0.9128 - lr: 9.1188e-07

# %%
# Show Train History
def show_train_history(train_history, train, validation, filename):  
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')  
    plt.xlabel('Epoch') 
    plt.ylabel(train)  
    plt.legend(['train', 'validation'], loc='upper left')  
    plt.savefig(filename)
    plt.show()

show_train_history(train_history, 'accuracy', 'val_accuracy', './picture/train_history5_accuracy.png')
show_train_history(train_history, 'loss', 'val_loss', './picture/train_history5_loss.png')

# %%
# Save Model
ResNet.save('./model5_ResNet.h5')

# %%
# Load Model
ResNet = load_model('./model5_ResNet.h5')

# %%
# Score
scores = ResNet.evaluate(x_test_norm, y_TestOneHot)
print()
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1]*100.0))
print("\t[Info]   Loss   of testing data = {:0.4f}".format(scores[0]))
# Out:
# 313/313 [==============================] - 5s 13ms/step - loss: 0.4243 - accuracy: 0.9128
#
# 	[Info] Accuracy of testing data = 91.3%
# 	[Info]   Loss   of testing data = 0.4243
