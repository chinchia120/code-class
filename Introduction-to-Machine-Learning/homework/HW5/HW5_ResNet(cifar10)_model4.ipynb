# %% [markdown]
# # **Assignment 5. Residual Network**
#
# * 看懂Residual Network樣板程式，解析其網路結構。
# * 基於樣板設計一個Residual Network, 與作業四VGG模型進行分析與比較(那個模型較好，為什麼?)。
# * (Optional)比較多個不同深度Residual Networks (以Residual Block為單位)，檢視”Deeper is Better”是否成立。

# %%
# Import
import os, torch
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
#from google.colab import drive
from keras.datasets import cifar10
from tensorflow.keras import regularizers, initializers, optimizers, metrics, utils
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, Input, Add, AveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Set Direction
drive.mount('/content/gdrive')
#os.chdir('/content/gdrive/My Drive/data/tmp/Introduction-to-Machine-Learning/homework/HW5')
os.chdir('/content/gdrive/My Drive/data/HW5')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Loading the CIFAR-10 Dataset
(x_train_image, y_train_label), (x_test_image, y_test_label) = cifar10.load_data()

# Declare Variables
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

def plot_multiimages(images, labels, prediction, idx, num=32):
    fig, ax = plt.subplots(4, 8, figsize=(12, 6))
    if num > 32: num = 32
    for i in range(0, num):
        ax = plt.subplot(4,8, 1+i)
        ax.imshow(images[idx])
        title = "l = " + class_names[int(labels[idx])]
        if len(prediction) > 0:
            title = "l = {}, p = {}".format(class_names[int(labels[idx])], class_names[prediction[idx]])
        else:
            title = "l = {}".format(class_names[int(labels[idx])])
        ax.set_title(title, fontsize=8)
        ax.set_xticks([]); ax.set_yticks([])
        idx+=1
    plt.tight_layout()
    plt.show()

plot_multiimages(x_test_image, y_test_label, [], 500, 32)

# Convert and Pre-Processing
x_train = x_train_image.reshape(len(x_train_image), 32, 32, 3).astype('float32')
x_test = x_test_image.reshape(len(x_test_image), 32, 32, 3).astype('float32')
x_train_norm = x_train / 255
x_test_norm = x_test / 255
y_TrainOneHot = utils.to_categorical(y_train_label)
y_TestOneHot = utils.to_categorical(y_test_label)

# %%
# Build a ResNet
def identity_block(X, filters):
    # Retrieve Filters
    F1, F2, F3 = filters
    # Save the Input Value
    X_shortcut = X

    # First Component of Main Path
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Second Component of Main Path
    X = Conv2D(filters=F2, kernel_size=(3, 3), strides=(1, 1), padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Third Component of Main Path
    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='same')(X)
    X = BatchNormalization()(X)

    # Final Step: Add Shortcut Value to Main Path, and Pass It Through a RELU Activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

def convolutional_block(X, filters):
    # Retrieve Filters
    F1, F2, F3 = filters
    # Save the Input Value
    X_shortcut = X

    ##### MAIN PATH #####
    # First Component of Main Path
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(2, 2), padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Second Component of Main Path
    X = Conv2D(filters=F2, kernel_size=(3, 3), strides=(1, 1), padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Third Component of Main Path
    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='same')(X)
    X = BatchNormalization()(X)

    ##### SHORTCUT PATH ####
    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(2, 2), padding='same')(X_shortcut)
    X_shortcut = BatchNormalization()(X_shortcut)

    # Final Step: Add Shortcut Value to Main Path, and Pass It Through a RELU Activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

def ResidualNetwork(input_shape=(32, 32, 3), classes=10):
    # Define the Input As a Tensor with Shape Input_Shape
    X_input = Input(input_shape)

    # Stage 1
    X = Conv2D(64, (3, 3), padding='same')(X_input)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Stage 2
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])
    X = identity_block(X, [16, 16, 64])

    # Stage 3
    X = convolutional_block(X, filters=[32, 32, 128])
    X = identity_block(X, [32, 32, 128])
    X = identity_block(X, [32, 32, 128])
    X = identity_block(X, [32, 32, 128])
    X = identity_block(X, [32, 32, 128])
    X = identity_block(X, [32, 32, 128])

    # Stage 4
    X = convolutional_block(X, filters=[64, 64, 256])
    X = identity_block(X, [64, 64, 256])
    X = identity_block(X, [64, 64, 256])
    X = identity_block(X, [64, 64, 256])
    X = identity_block(X, [64, 64, 256])
    X = identity_block(X, [64, 64, 256])

    # Stage 5
    X = convolutional_block(X, filters=[128, 128, 512])
    X = identity_block(X, [128, 128, 512])
    X = identity_block(X, [128, 128, 512])
    X = identity_block(X, [128, 128, 512])

    # Stage 6
    X = convolutional_block(X, filters=[128, 128, 512])
    X = identity_block(X, [128, 128, 512])

    # AVGPOOL
    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)

    # Output Layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax')(X)

    # Create Model
    ResNet_model = Model(inputs=X_input, outputs=X)
    
    return ResNet_model

ResNet = ResidualNetwork(input_shape = (32, 32, 3), classes = 10)

# Summary
ResNet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 64)   1792        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   1040        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   1088        ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 64)   0           ['batch_normalization_3[0][0]',
#                                                                   'activation[0][0]']
#
#  activation_3 (Activation)      (None, 32, 32, 64)   0           ['add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 16)   1040        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 64)   1088        ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 64)   0           ['batch_normalization_6[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 64)   0           ['add_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 16)   1040        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 64)   1088        ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 64)   0           ['batch_normalization_9[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 32, 32, 64)   0           ['add_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 32, 32, 64)   0           ['batch_normalization_12[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_12 (Activation)     (None, 32, 32, 64)   0           ['add_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 16)  64          ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 16)  64          ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 32, 32, 64)   0           ['batch_normalization_15[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 32, 32, 64)   0           ['add_4[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 16)  64          ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 32, 32, 64)   0           ['batch_normalization_18[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 64)   0           ['add_5[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 32)   2080        ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 32)  128         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 32)  128         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 128)  4224        ['activation_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 128)  8320        ['activation_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 128)  512        ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 16, 16, 128)  0           ['batch_normalization_21[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  activation_21 (Activation)     (None, 16, 16, 128)  0           ['add_6[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 32)   4128        ['activation_21[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_22[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 32)  128         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 128)  4224        ['activation_23[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 16, 16, 128)  0           ['batch_normalization_25[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_24 (Activation)     (None, 16, 16, 128)  0           ['add_7[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 32)   4128        ['activation_24[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 32)  128         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_25[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 32)  128         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 128)  4224        ['activation_26[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 128)  512        ['conv2d_28[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 16, 16, 128)  0           ['batch_normalization_28[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 16, 16, 128)  0           ['add_8[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 32)   4128        ['activation_27[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 32)  128         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_28[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 32)  128         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 128)  4224        ['activation_29[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 128)  512        ['conv2d_31[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 16, 16, 128)  0           ['batch_normalization_31[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 16, 16, 128)  0           ['add_9[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 32)   4128        ['activation_30[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 32)  128         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_31[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 32)  128         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 128)  4224        ['activation_32[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 128)  512        ['conv2d_34[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 16, 16, 128)  0           ['batch_normalization_34[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 16, 16, 128)  0           ['add_10[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 32)   4128        ['activation_33[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 32)  128         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_34[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 32)  128         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 128)  4224        ['activation_35[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 128)  512        ['conv2d_37[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 16, 16, 128)  0           ['batch_normalization_37[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 16, 16, 128)  0           ['add_11[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 64)     8256        ['activation_36[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 64)    256         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_37[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 64)    256         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 256)    16640       ['activation_38[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 256)    33024       ['activation_36[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_41[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 8, 8, 256)    0           ['batch_normalization_40[0][0]',
#                                                                   'batch_normalization_41[0][0]']
#
#  activation_39 (Activation)     (None, 8, 8, 256)    0           ['add_12[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 64)     16448       ['activation_39[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 8, 64)    256         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_40[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 8, 8, 64)    256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 256)    16640       ['activation_41[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_44[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 8, 8, 256)    0           ['batch_normalization_44[0][0]',
#                                                                   'activation_39[0][0]']
#
#  activation_42 (Activation)     (None, 8, 8, 256)    0           ['add_13[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 64)     16448       ['activation_42[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 64)    256         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_43[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 8, 8, 64)    256         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 256)    16640       ['activation_44[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_47[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 8, 8, 256)    0           ['batch_normalization_47[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 8, 8, 256)    0           ['add_14[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 8, 8, 64)     16448       ['activation_45[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 8, 8, 64)    256         ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_46[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 8, 8, 64)    256         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 8, 8, 256)    16640       ['activation_47[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_50[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 8, 8, 256)    0           ['batch_normalization_50[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 8, 8, 256)    0           ['add_15[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 8, 8, 64)     16448       ['activation_48[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 8, 8, 64)    256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_49[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 8, 8, 64)    256         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 8, 8, 256)    16640       ['activation_50[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_53[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 8, 8, 256)    0           ['batch_normalization_53[0][0]',
#                                                                   'activation_48[0][0]']
#
#  activation_51 (Activation)     (None, 8, 8, 256)    0           ['add_16[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 8, 8, 64)     16448       ['activation_51[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 8, 8, 64)    256         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_52[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 8, 8, 64)    256         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 8, 8, 256)    16640       ['activation_53[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_56[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 8, 8, 256)    0           ['batch_normalization_56[0][0]',
#                                                                   'activation_51[0][0]']
#
#  activation_54 (Activation)     (None, 8, 8, 256)    0           ['add_17[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 4, 4, 128)    32896       ['activation_54[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 4, 4, 128)   512         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_55[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 4, 4, 128)   512         ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 4, 4, 512)    66048       ['activation_56[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 4, 4, 512)    131584      ['activation_54[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_59[0][0]']
#  ormalization)
#
#  batch_normalization_60 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_60[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_59[0][0]',
#                                                                   'batch_normalization_60[0][0]']
#
#  activation_57 (Activation)     (None, 4, 4, 512)    0           ['add_18[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 4, 4, 128)    65664       ['activation_57[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 4, 4, 128)   512         ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_58[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 4, 4, 128)   512         ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 4, 4, 512)    66048       ['activation_59[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_63[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_63[0][0]',
#                                                                   'activation_57[0][0]']
#
#  activation_60 (Activation)     (None, 4, 4, 512)    0           ['add_19[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 4, 4, 128)    65664       ['activation_60[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 4, 4, 128)   512         ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_61[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 4, 4, 128)   512         ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_65[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 4, 4, 512)    66048       ['activation_62[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_66[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_66[0][0]',
#                                                                   'activation_60[0][0]']
#
#  activation_63 (Activation)     (None, 4, 4, 512)    0           ['add_20[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 4, 4, 128)    65664       ['activation_63[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 4, 4, 128)   512         ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_67[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_64[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 4, 4, 128)   512         ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 4, 4, 512)    66048       ['activation_65[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_69[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_69[0][0]',
#                                                                   'activation_63[0][0]']
#
#  activation_66 (Activation)     (None, 4, 4, 512)    0           ['add_21[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 2, 2, 128)    65664       ['activation_66[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 2, 2, 128)   512         ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_70[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 2, 2, 128)    147584      ['activation_67[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 2, 2, 128)   512         ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_71[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 2, 2, 512)    66048       ['activation_68[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 2, 2, 512)    262656      ['activation_66[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_72[0][0]']
#  ormalization)
#
#  batch_normalization_73 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_73[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_72[0][0]',
#                                                                   'batch_normalization_73[0][0]']
#
#  activation_69 (Activation)     (None, 2, 2, 512)    0           ['add_22[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 2, 2, 128)    65664       ['activation_69[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 2, 2, 128)   512         ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 2, 2, 128)    147584      ['activation_70[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 2, 2, 128)   512         ['conv2d_75[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_75[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 2, 2, 512)    66048       ['activation_71[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_76[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_76[0][0]',
#                                                                   'activation_69[0][0]']
#
#  activation_72 (Activation)     (None, 2, 2, 512)    0           ['add_23[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 512)   0           ['activation_72[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 512)          0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 10)           5130        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 2,668,106
# Trainable params: 2,647,882
# Non-trainable params: 20,224
# __________________________________________________________________________________________________

# %%
# Learning Rate Scheduler
def scheduler(epoch, lr):
    if epoch < 80:
        return lr
    else:
        return lr * tf.math.exp(-0.1)
    
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
# Train ResNet Model
ResNet.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
img_gen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, rotation_range=10, horizontal_flip=True, zoom_range=0.1)
img_gen.fit(x_train_norm)
train_history = ResNet.fit(img_gen.flow(x_train_norm, y_TrainOneHot, batch_size=16), steps_per_epoch=1500, epochs=150, callbacks=[callback], shuffle=True, validation_data = (x_test_norm, y_TestOneHot), verbose=1)
# Out:
# Epoch 1/150
# 1500/1500 [==============================] - 91s 48ms/step - loss: 2.0270 - accuracy: 0.2758 - val_loss: 2.2336 - val_accuracy: 0.3038 - lr: 0.0010
# Epoch 2/150
# 1500/1500 [==============================] - 70s 46ms/step - loss: 1.6691 - accuracy: 0.3902 - val_loss: 1.7578 - val_accuracy: 0.3711 - lr: 0.0010
# Epoch 3/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 1.5613 - accuracy: 0.4367 - val_loss: 1.4162 - val_accuracy: 0.4824 - lr: 0.0010
# Epoch 4/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 1.4247 - accuracy: 0.4885 - val_loss: 1.5449 - val_accuracy: 0.4867 - lr: 0.0010
# Epoch 5/150
# 1500/1500 [==============================] - 73s 48ms/step - loss: 1.3258 - accuracy: 0.5245 - val_loss: 1.2306 - val_accuracy: 0.5653 - lr: 0.0010
# Epoch 6/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 1.2036 - accuracy: 0.5700 - val_loss: 1.2054 - val_accuracy: 0.5788 - lr: 0.0010
# Epoch 7/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 1.1174 - accuracy: 0.6020 - val_loss: 1.2877 - val_accuracy: 0.5689 - lr: 0.0010
# Epoch 8/150
# 1500/1500 [==============================] - 72s 48ms/step - loss: 1.0459 - accuracy: 0.6336 - val_loss: 1.2115 - val_accuracy: 0.5975 - lr: 0.0010
# Epoch 9/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.9676 - accuracy: 0.6607 - val_loss: 1.1553 - val_accuracy: 0.6284 - lr: 0.0010
# Epoch 10/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.9145 - accuracy: 0.6751 - val_loss: 1.1278 - val_accuracy: 0.6448 - lr: 0.0010
# Epoch 11/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.8762 - accuracy: 0.6943 - val_loss: 0.9326 - val_accuracy: 0.6857 - lr: 0.0010
# Epoch 12/150
# 1500/1500 [==============================] - 70s 47ms/step - loss: 0.8263 - accuracy: 0.7104 - val_loss: 1.0278 - val_accuracy: 0.6657 - lr: 0.0010
# Epoch 13/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.7896 - accuracy: 0.7218 - val_loss: 0.8121 - val_accuracy: 0.7254 - lr: 0.0010
# Epoch 14/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.7538 - accuracy: 0.7351 - val_loss: 1.0235 - val_accuracy: 0.6679 - lr: 0.0010
# Epoch 15/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.7409 - accuracy: 0.7423 - val_loss: 0.7316 - val_accuracy: 0.7448 - lr: 0.0010
# Epoch 16/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.7103 - accuracy: 0.7546 - val_loss: 0.8132 - val_accuracy: 0.7317 - lr: 0.0010
# Epoch 17/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.6964 - accuracy: 0.7583 - val_loss: 0.9186 - val_accuracy: 0.7093 - lr: 0.0010
# Epoch 18/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.6687 - accuracy: 0.7666 - val_loss: 0.7008 - val_accuracy: 0.7623 - lr: 0.0010
# Epoch 19/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.6600 - accuracy: 0.7713 - val_loss: 0.6175 - val_accuracy: 0.7893 - lr: 0.0010
# Epoch 20/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.6468 - accuracy: 0.7744 - val_loss: 0.7531 - val_accuracy: 0.7528 - lr: 0.0010
# Epoch 21/150
# 1500/1500 [==============================] - 65s 44ms/step - loss: 0.6123 - accuracy: 0.7886 - val_loss: 1.0101 - val_accuracy: 0.7111 - lr: 0.0010
# Epoch 22/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.5986 - accuracy: 0.7899 - val_loss: 0.8160 - val_accuracy: 0.7289 - lr: 0.0010
# Epoch 23/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.5897 - accuracy: 0.7959 - val_loss: 1.2832 - val_accuracy: 0.6513 - lr: 0.0010
# Epoch 24/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.5743 - accuracy: 0.7990 - val_loss: 0.7059 - val_accuracy: 0.7696 - lr: 0.0010
# Epoch 25/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.5666 - accuracy: 0.8035 - val_loss: 0.6484 - val_accuracy: 0.7792 - lr: 0.0010
# Epoch 26/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.5513 - accuracy: 0.8113 - val_loss: 0.8098 - val_accuracy: 0.7339 - lr: 0.0010
# Epoch 27/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.5393 - accuracy: 0.8107 - val_loss: 0.7514 - val_accuracy: 0.7589 - lr: 0.0010
# Epoch 28/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.5308 - accuracy: 0.8158 - val_loss: 0.7377 - val_accuracy: 0.7611 - lr: 0.0010
# Epoch 29/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.5254 - accuracy: 0.8162 - val_loss: 0.6273 - val_accuracy: 0.7919 - lr: 0.0010
# Epoch 30/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.5158 - accuracy: 0.8200 - val_loss: 0.6297 - val_accuracy: 0.7944 - lr: 0.0010
# Epoch 31/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.5037 - accuracy: 0.8253 - val_loss: 0.7019 - val_accuracy: 0.7748 - lr: 0.0010
# Epoch 32/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.4926 - accuracy: 0.8259 - val_loss: 0.6213 - val_accuracy: 0.7910 - lr: 0.0010
# Epoch 33/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.4868 - accuracy: 0.8308 - val_loss: 0.5421 - val_accuracy: 0.8169 - lr: 0.0010
# Epoch 34/150
# 1500/1500 [==============================] - 65s 44ms/step - loss: 0.4704 - accuracy: 0.8347 - val_loss: 0.5793 - val_accuracy: 0.8061 - lr: 0.0010
# Epoch 35/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.4659 - accuracy: 0.8353 - val_loss: 0.5620 - val_accuracy: 0.8186 - lr: 0.0010
# Epoch 36/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.4656 - accuracy: 0.8370 - val_loss: 0.5284 - val_accuracy: 0.8218 - lr: 0.0010
# Epoch 37/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.4547 - accuracy: 0.8425 - val_loss: 0.6972 - val_accuracy: 0.7809 - lr: 0.0010
# Epoch 38/150
# 1500/1500 [==============================] - 67s 44ms/step - loss: 0.4429 - accuracy: 0.8455 - val_loss: 0.5629 - val_accuracy: 0.8230 - lr: 0.0010
# Epoch 39/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.4376 - accuracy: 0.8463 - val_loss: 0.6407 - val_accuracy: 0.7949 - lr: 0.0010
# Epoch 40/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.4274 - accuracy: 0.8512 - val_loss: 0.5052 - val_accuracy: 0.8349 - lr: 0.0010
# Epoch 41/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.4311 - accuracy: 0.8502 - val_loss: 0.5409 - val_accuracy: 0.8185 - lr: 0.0010
# Epoch 42/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.4205 - accuracy: 0.8525 - val_loss: 0.7038 - val_accuracy: 0.7802 - lr: 0.0010
# Epoch 43/150
# 1500/1500 [==============================] - 67s 44ms/step - loss: 0.4035 - accuracy: 0.8593 - val_loss: 0.5490 - val_accuracy: 0.8237 - lr: 0.0010
# Epoch 44/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.4145 - accuracy: 0.8562 - val_loss: 0.4751 - val_accuracy: 0.8415 - lr: 0.0010
# Epoch 45/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.4009 - accuracy: 0.8592 - val_loss: 0.4460 - val_accuracy: 0.8468 - lr: 0.0010
# Epoch 46/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.3917 - accuracy: 0.8647 - val_loss: 0.5407 - val_accuracy: 0.8262 - lr: 0.0010
# Epoch 47/150
# 1500/1500 [==============================] - 67s 44ms/step - loss: 0.3873 - accuracy: 0.8665 - val_loss: 0.5161 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 48/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.3893 - accuracy: 0.8656 - val_loss: 0.4801 - val_accuracy: 0.8419 - lr: 0.0010
# Epoch 49/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.3784 - accuracy: 0.8707 - val_loss: 0.4649 - val_accuracy: 0.8450 - lr: 0.0010
# Epoch 50/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.3799 - accuracy: 0.8679 - val_loss: 0.5208 - val_accuracy: 0.8329 - lr: 0.0010
# Epoch 51/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.3738 - accuracy: 0.8700 - val_loss: 0.4959 - val_accuracy: 0.8427 - lr: 0.0010
# Epoch 52/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.3645 - accuracy: 0.8718 - val_loss: 0.5415 - val_accuracy: 0.8323 - lr: 0.0010
# Epoch 53/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.3599 - accuracy: 0.8756 - val_loss: 0.5168 - val_accuracy: 0.8374 - lr: 0.0010
# Epoch 54/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.3630 - accuracy: 0.8719 - val_loss: 0.4210 - val_accuracy: 0.8626 - lr: 0.0010
# Epoch 55/150
# 1500/1500 [==============================] - 68s 46ms/step - loss: 0.3524 - accuracy: 0.8793 - val_loss: 0.4036 - val_accuracy: 0.8649 - lr: 0.0010
# Epoch 56/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.3537 - accuracy: 0.8772 - val_loss: 0.5328 - val_accuracy: 0.8309 - lr: 0.0010
# Epoch 57/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.3374 - accuracy: 0.8806 - val_loss: 0.5179 - val_accuracy: 0.8460 - lr: 0.0010
# Epoch 58/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.3352 - accuracy: 0.8835 - val_loss: 0.4551 - val_accuracy: 0.8533 - lr: 0.0010
# Epoch 59/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.3393 - accuracy: 0.8828 - val_loss: 0.5053 - val_accuracy: 0.8407 - lr: 0.0010
# Epoch 60/150
# 1500/1500 [==============================] - 65s 44ms/step - loss: 0.3278 - accuracy: 0.8856 - val_loss: 0.4541 - val_accuracy: 0.8523 - lr: 0.0010
# Epoch 61/150
# 1500/1500 [==============================] - 67s 44ms/step - loss: 0.3288 - accuracy: 0.8847 - val_loss: 0.4219 - val_accuracy: 0.8630 - lr: 0.0010
# Epoch 62/150
# 1500/1500 [==============================] - 70s 47ms/step - loss: 0.3269 - accuracy: 0.8850 - val_loss: 0.4279 - val_accuracy: 0.8627 - lr: 0.0010
# Epoch 63/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.3197 - accuracy: 0.8886 - val_loss: 0.4662 - val_accuracy: 0.8459 - lr: 0.0010
# Epoch 64/150
# 1500/1500 [==============================] - 65s 44ms/step - loss: 0.3157 - accuracy: 0.8895 - val_loss: 0.4404 - val_accuracy: 0.8517 - lr: 0.0010
# Epoch 65/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.3137 - accuracy: 0.8892 - val_loss: 0.6052 - val_accuracy: 0.8117 - lr: 0.0010
# Epoch 66/150
# 1500/1500 [==============================] - 70s 46ms/step - loss: 0.3090 - accuracy: 0.8930 - val_loss: 0.4386 - val_accuracy: 0.8555 - lr: 0.0010
# Epoch 67/150
# 1500/1500 [==============================] - 64s 43ms/step - loss: 0.3041 - accuracy: 0.8955 - val_loss: 0.4409 - val_accuracy: 0.8564 - lr: 0.0010
# Epoch 68/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.3043 - accuracy: 0.8924 - val_loss: 0.5015 - val_accuracy: 0.8341 - lr: 0.0010
# Epoch 69/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.3073 - accuracy: 0.8937 - val_loss: 0.4640 - val_accuracy: 0.8487 - lr: 0.0010
# Epoch 70/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.2966 - accuracy: 0.8957 - val_loss: 0.4090 - val_accuracy: 0.8662 - lr: 0.0010
# Epoch 71/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.2967 - accuracy: 0.8982 - val_loss: 0.4220 - val_accuracy: 0.8571 - lr: 0.0010
# Epoch 72/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.2986 - accuracy: 0.8955 - val_loss: 0.4054 - val_accuracy: 0.8704 - lr: 0.0010
# Epoch 73/150
# 1500/1500 [==============================] - 67s 44ms/step - loss: 0.2906 - accuracy: 0.8961 - val_loss: 0.3769 - val_accuracy: 0.8747 - lr: 0.0010
# Epoch 74/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.2882 - accuracy: 0.8980 - val_loss: 0.4309 - val_accuracy: 0.8626 - lr: 0.0010
# Epoch 75/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.2824 - accuracy: 0.9017 - val_loss: 0.4317 - val_accuracy: 0.8570 - lr: 0.0010
# Epoch 76/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.2759 - accuracy: 0.9041 - val_loss: 0.4118 - val_accuracy: 0.8673 - lr: 0.0010
# Epoch 77/150
# 1500/1500 [==============================] - 70s 46ms/step - loss: 0.2825 - accuracy: 0.8986 - val_loss: 0.3934 - val_accuracy: 0.8732 - lr: 0.0010
# Epoch 78/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.2789 - accuracy: 0.9017 - val_loss: 0.4977 - val_accuracy: 0.8458 - lr: 0.0010
# Epoch 79/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.2675 - accuracy: 0.9061 - val_loss: 0.4020 - val_accuracy: 0.8706 - lr: 0.0010
# Epoch 80/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.2671 - accuracy: 0.9057 - val_loss: 0.4520 - val_accuracy: 0.8559 - lr: 0.0010
# Epoch 81/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.2576 - accuracy: 0.9083 - val_loss: 0.4181 - val_accuracy: 0.8693 - lr: 9.0484e-04
# Epoch 82/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.2499 - accuracy: 0.9117 - val_loss: 0.4687 - val_accuracy: 0.8615 - lr: 8.1873e-04
# Epoch 83/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.2318 - accuracy: 0.9196 - val_loss: 0.4056 - val_accuracy: 0.8664 - lr: 7.4082e-04
# Epoch 84/150
# 1500/1500 [==============================] - 68s 46ms/step - loss: 0.2197 - accuracy: 0.9218 - val_loss: 0.4615 - val_accuracy: 0.8618 - lr: 6.7032e-04
# Epoch 85/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.2130 - accuracy: 0.9263 - val_loss: 0.3538 - val_accuracy: 0.8881 - lr: 6.0653e-04
# Epoch 86/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.2041 - accuracy: 0.9266 - val_loss: 0.3468 - val_accuracy: 0.8901 - lr: 5.4881e-04
# Epoch 87/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.1956 - accuracy: 0.9300 - val_loss: 0.3545 - val_accuracy: 0.8876 - lr: 4.9659e-04
# Epoch 88/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.1854 - accuracy: 0.9339 - val_loss: 0.3693 - val_accuracy: 0.8865 - lr: 4.4933e-04
# Epoch 89/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1801 - accuracy: 0.9370 - val_loss: 0.3453 - val_accuracy: 0.8934 - lr: 4.0657e-04
# Epoch 90/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.1780 - accuracy: 0.9360 - val_loss: 0.3856 - val_accuracy: 0.8820 - lr: 3.6788e-04
# Epoch 91/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.1726 - accuracy: 0.9382 - val_loss: 0.3423 - val_accuracy: 0.8946 - lr: 3.3287e-04
# Epoch 92/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.1598 - accuracy: 0.9438 - val_loss: 0.3670 - val_accuracy: 0.8902 - lr: 3.0119e-04
# Epoch 93/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1590 - accuracy: 0.9431 - val_loss: 0.3386 - val_accuracy: 0.8966 - lr: 2.7253e-04
# Epoch 94/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1556 - accuracy: 0.9446 - val_loss: 0.3689 - val_accuracy: 0.8927 - lr: 2.4660e-04
# Epoch 95/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1529 - accuracy: 0.9475 - val_loss: 0.3396 - val_accuracy: 0.8973 - lr: 2.2313e-04
# Epoch 96/150
# 1500/1500 [==============================] - 68s 46ms/step - loss: 0.1433 - accuracy: 0.9485 - val_loss: 0.3374 - val_accuracy: 0.8991 - lr: 2.0190e-04
# Epoch 97/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1416 - accuracy: 0.9493 - val_loss: 0.3379 - val_accuracy: 0.8988 - lr: 1.8268e-04
# Epoch 98/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.1425 - accuracy: 0.9494 - val_loss: 0.3377 - val_accuracy: 0.8995 - lr: 1.6530e-04
# Epoch 99/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.1427 - accuracy: 0.9488 - val_loss: 0.3265 - val_accuracy: 0.9027 - lr: 1.4957e-04
# Epoch 100/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1387 - accuracy: 0.9516 - val_loss: 0.3389 - val_accuracy: 0.8981 - lr: 1.3534e-04
# Epoch 101/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1273 - accuracy: 0.9545 - val_loss: 0.3424 - val_accuracy: 0.8990 - lr: 1.2246e-04
# Epoch 102/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.1325 - accuracy: 0.9518 - val_loss: 0.3397 - val_accuracy: 0.8992 - lr: 1.1080e-04
# Epoch 103/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.1268 - accuracy: 0.9557 - val_loss: 0.3364 - val_accuracy: 0.8995 - lr: 1.0026e-04
# Epoch 104/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.1205 - accuracy: 0.9570 - val_loss: 0.3306 - val_accuracy: 0.9031 - lr: 9.0718e-05
# Epoch 105/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.1267 - accuracy: 0.9558 - val_loss: 0.3357 - val_accuracy: 0.9005 - lr: 8.2085e-05
# Epoch 106/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1231 - accuracy: 0.9570 - val_loss: 0.3494 - val_accuracy: 0.8971 - lr: 7.4273e-05
# Epoch 107/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.1205 - accuracy: 0.9562 - val_loss: 0.3373 - val_accuracy: 0.8996 - lr: 6.7205e-05
# Epoch 108/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1234 - accuracy: 0.9562 - val_loss: 0.3425 - val_accuracy: 0.8991 - lr: 6.0810e-05
# Epoch 109/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1256 - accuracy: 0.9555 - val_loss: 0.3318 - val_accuracy: 0.9013 - lr: 5.5023e-05
# Epoch 110/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1194 - accuracy: 0.9580 - val_loss: 0.3370 - val_accuracy: 0.9006 - lr: 4.9787e-05
# Epoch 111/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.1198 - accuracy: 0.9561 - val_loss: 0.3329 - val_accuracy: 0.9015 - lr: 4.5049e-05
# Epoch 112/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1176 - accuracy: 0.9592 - val_loss: 0.3340 - val_accuracy: 0.9030 - lr: 4.0762e-05
# Epoch 113/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1151 - accuracy: 0.9609 - val_loss: 0.3281 - val_accuracy: 0.9047 - lr: 3.6883e-05
# Epoch 114/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1150 - accuracy: 0.9590 - val_loss: 0.3332 - val_accuracy: 0.9035 - lr: 3.3373e-05
# Epoch 115/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.1150 - accuracy: 0.9601 - val_loss: 0.3327 - val_accuracy: 0.9026 - lr: 3.0197e-05
# Epoch 116/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1098 - accuracy: 0.9620 - val_loss: 0.3349 - val_accuracy: 0.9019 - lr: 2.7324e-05
# Epoch 117/150
# 1500/1500 [==============================] - 64s 43ms/step - loss: 0.1148 - accuracy: 0.9590 - val_loss: 0.3310 - val_accuracy: 0.9019 - lr: 2.4723e-05
# Epoch 118/150
# 1500/1500 [==============================] - 64s 43ms/step - loss: 0.1119 - accuracy: 0.9607 - val_loss: 0.3329 - val_accuracy: 0.9013 - lr: 2.2371e-05
# Epoch 119/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.1103 - accuracy: 0.9613 - val_loss: 0.3376 - val_accuracy: 0.9006 - lr: 2.0242e-05
# Epoch 120/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1153 - accuracy: 0.9589 - val_loss: 0.3380 - val_accuracy: 0.9015 - lr: 1.8316e-05
# Epoch 121/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.1118 - accuracy: 0.9599 - val_loss: 0.3351 - val_accuracy: 0.9015 - lr: 1.6573e-05
# Epoch 122/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.1162 - accuracy: 0.9584 - val_loss: 0.3346 - val_accuracy: 0.9020 - lr: 1.4996e-05
# Epoch 123/150
# 1500/1500 [==============================] - 65s 44ms/step - loss: 0.1106 - accuracy: 0.9596 - val_loss: 0.3347 - val_accuracy: 0.9027 - lr: 1.3569e-05
# Epoch 124/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1155 - accuracy: 0.9596 - val_loss: 0.3334 - val_accuracy: 0.9020 - lr: 1.2277e-05
# Epoch 125/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1123 - accuracy: 0.9599 - val_loss: 0.3282 - val_accuracy: 0.9032 - lr: 1.1109e-05
# Epoch 126/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.1074 - accuracy: 0.9617 - val_loss: 0.3370 - val_accuracy: 0.9011 - lr: 1.0052e-05
# Epoch 127/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.1111 - accuracy: 0.9601 - val_loss: 0.3348 - val_accuracy: 0.9020 - lr: 9.0953e-06
# Epoch 128/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1160 - accuracy: 0.9605 - val_loss: 0.3347 - val_accuracy: 0.9027 - lr: 8.2297e-06
# Epoch 129/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1144 - accuracy: 0.9595 - val_loss: 0.3343 - val_accuracy: 0.9008 - lr: 7.4466e-06
# Epoch 130/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.1140 - accuracy: 0.9585 - val_loss: 0.3332 - val_accuracy: 0.9019 - lr: 6.7379e-06
# Epoch 131/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1122 - accuracy: 0.9601 - val_loss: 0.3318 - val_accuracy: 0.9026 - lr: 6.0967e-06
# Epoch 132/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1168 - accuracy: 0.9587 - val_loss: 0.3308 - val_accuracy: 0.9017 - lr: 5.5165e-06
# Epoch 133/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.1078 - accuracy: 0.9615 - val_loss: 0.3312 - val_accuracy: 0.9019 - lr: 4.9916e-06
# Epoch 134/150
# 1500/1500 [==============================] - 65s 44ms/step - loss: 0.1129 - accuracy: 0.9616 - val_loss: 0.3283 - val_accuracy: 0.9035 - lr: 4.5166e-06
# Epoch 135/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1123 - accuracy: 0.9605 - val_loss: 0.3300 - val_accuracy: 0.9029 - lr: 4.0868e-06
# Epoch 136/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1122 - accuracy: 0.9597 - val_loss: 0.3313 - val_accuracy: 0.9033 - lr: 3.6979e-06
# Epoch 137/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.1102 - accuracy: 0.9597 - val_loss: 0.3313 - val_accuracy: 0.9031 - lr: 3.3460e-06
# Epoch 138/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1108 - accuracy: 0.9609 - val_loss: 0.3311 - val_accuracy: 0.9018 - lr: 3.0275e-06
# Epoch 139/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.1120 - accuracy: 0.9613 - val_loss: 0.3287 - val_accuracy: 0.9040 - lr: 2.7394e-06
# Epoch 140/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1104 - accuracy: 0.9597 - val_loss: 0.3328 - val_accuracy: 0.9021 - lr: 2.4787e-06
# Epoch 141/150
# 1500/1500 [==============================] - 69s 46ms/step - loss: 0.1037 - accuracy: 0.9639 - val_loss: 0.3339 - val_accuracy: 0.9023 - lr: 2.2429e-06
# Epoch 142/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1114 - accuracy: 0.9605 - val_loss: 0.3341 - val_accuracy: 0.9020 - lr: 2.0294e-06
# Epoch 143/150
# 1500/1500 [==============================] - 67s 45ms/step - loss: 0.1113 - accuracy: 0.9604 - val_loss: 0.3319 - val_accuracy: 0.9024 - lr: 1.8363e-06
# Epoch 144/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1061 - accuracy: 0.9638 - val_loss: 0.3327 - val_accuracy: 0.9020 - lr: 1.6616e-06
# Epoch 145/150
# 1500/1500 [==============================] - 68s 45ms/step - loss: 0.1108 - accuracy: 0.9594 - val_loss: 0.3331 - val_accuracy: 0.9025 - lr: 1.5034e-06
# Epoch 146/150
# 1500/1500 [==============================] - 66s 44ms/step - loss: 0.1040 - accuracy: 0.9636 - val_loss: 0.3366 - val_accuracy: 0.9017 - lr: 1.3604e-06
# Epoch 147/150
# 1500/1500 [==============================] - 65s 44ms/step - loss: 0.1158 - accuracy: 0.9588 - val_loss: 0.3309 - val_accuracy: 0.9019 - lr: 1.2309e-06
# Epoch 148/150
# 1500/1500 [==============================] - 71s 47ms/step - loss: 0.1130 - accuracy: 0.9603 - val_loss: 0.3323 - val_accuracy: 0.9030 - lr: 1.1138e-06
# Epoch 149/150
# 1500/1500 [==============================] - 65s 43ms/step - loss: 0.1110 - accuracy: 0.9605 - val_loss: 0.3317 - val_accuracy: 0.9022 - lr: 1.0078e-06
# Epoch 150/150
# 1500/1500 [==============================] - 65s 44ms/step - loss: 0.1070 - accuracy: 0.9628 - val_loss: 0.3326 - val_accuracy: 0.9026 - lr: 9.1188e-07

# %%
# Show Train History
def show_train_history(train_history, train, validation, filename):  
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')  
    plt.xlabel('Epoch') 
    plt.ylabel(train)  
    plt.legend(['train', 'validation'], loc='upper left')  
    plt.savefig(filename)
    plt.show()

show_train_history(train_history, 'accuracy', 'val_accuracy', './picture/train_history4_accuracy.png')
show_train_history(train_history, 'loss', 'val_loss', './picture/train_history4_loss.png')

# %%
# Save Model
ResNet.save('./model4_ResNet.h5')

# %%
# Load Model
ResNet = load_model('./model4_ResNet.h5')

# %%
# Score
scores = ResNet.evaluate(x_test_norm, y_TestOneHot)
print()
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1]*100.0))
print("\t[Info]   Loss   of testing data = {:0.4f}".format(scores[0]))
# Out:
# 313/313 [==============================] - 77s 228ms/step - loss: 0.3326 - accuracy: 0.9026
#
# 	[Info] Accuracy of testing data = 90.3%
# 	[Info]   Loss   of testing data = 0.3326
